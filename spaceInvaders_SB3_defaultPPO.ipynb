# %% [markdown]
# # Stable Baselines3 - Train on Atari Games
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Collecting stable-baselines3>=2.0.0a4 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading stable_baselines3-2.4.0a7-py3-none-any.whl.metadata (5.1 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.4.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.8.0)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (9.4.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.32.3)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (6.4.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Downloading stable_baselines3-2.4.0a7-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.9/182.9 kB 9.1 MB/s eta 0:00:00
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 16.5 MB/s eta 0:00:00
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 31.2 MB/s eta 0:00:00
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446661 sha256=58c33f36d5a4f7598596708929c79cf27d6db5ee2ee1a5d6f20a5b4ef8327592
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-1.3.0 stable-baselines3-2.4.0a7

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# %%
from google.colab import files
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Training on Atari
#
# We will use atari wrapper (it will downsample the image and convert it to gray scale).
#
# About Atari preprocessing: [Frame Skipping and Pre-Processing for Deep Q-Networks on Atari 2600 Games](https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/)
#
# ![Pong](https://cdn-images-1.medium.com/max/800/1*UHYJE7lF8IDZS_U5SsAFUQ.gif)

# %%
# There already exists an environment generator that will make and wrap atari environments correctly.
env = make_atari_env("SpaceInvadersNoFrameskip-v4", n_envs=8, seed=0)
# Stack 4 frames
vec_env = VecFrameStack(env, n_stack=4)

# %%
import os
models_dir = "models/PPO"
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from stable_baselines3.common.callbacks import CheckpointCallback
# Save a checkpoint every 2_000_000 steps
checkpoint_callback = CheckpointCallback(save_freq=250000, save_path="./gdrive/MyDrive/models/PPO",
                                         name_prefix="ppo_spaceInvadersPpoDefaults")

# %% [markdown]
# from collections import OrderedDict \n
# hyperParamsDictForPpo = OrderedDict([('batch_size', 256), ('clip_range', 0.001), ('ent_coef', 0.01), ('env_wrapper', ['stable_baselines3.common.atari_wrappers.AtariWrapper']), ('frame_stack', 4), ('learning_rate', 0.0001), ('n_envs', 8), ('n_epochs', 4), ('n_steps', 128), ('n_timesteps', 100000), ('policy', 'CnnPolicy'), ('vf_coef', 0.5), ('normalize', False)])

# %%
# model = PPO("CnnPolicy", vec_env, verbose=1, tensorboard_log="./gdrive/MyDrive/models/ppo_spaceinvaders_tensorboard/",
#             batch_size=256,
#             clip_range=0.001,
#             ent_coef=0.01,
#             learning_rate=0.0001,
#             n_epochs=4,
#             n_steps=128,
#             vf_coef=0.5
#             )
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# create model with default settings

# stable_baselines3.ppo.PPO(policy, env, learning_rate=0.0003, n_steps=2048, batch_size=64, n_epochs=10, gamma=0.99, gae_lambda=0.95, clip_range=0.2, clip_range_vf=None, normalize_advantage=True, ent_coef=0.0, vf_coef=0.5, max_grad_norm=0.5, use_sde=False, sde_sample_freq=-1, rollout_buffer_class=None, rollout_buffer_kwargs=None, target_kl=None, stats_window_size=100, tensorboard_log=None, policy_kwargs=None, verbose=0, seed=None, device='auto', _init_setup_model=True)

model = PPO("CnnPolicy", vec_env, verbose=1, tensorboard_log="./gdrive/MyDrive/models/ppo_spaceinvaders_tensorboard/"
            )

# model.set_env(vec_env)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model = PPO.load("/content/gdrive/MyDrive/models/PPO/ppo_spaceInvadersLvl4Train_33955088_steps", verbose=1, tensorboard_log="./gdrive/MyDrive/models/ppo_spaceinvaders_tensorboard/",
                 force_reset=False)
model.set_env(vec_env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# Stop training when the model reaches the reward threshold
ptsPerInvaderCol = 60
colPerLevel = 12
ptsPerLevel = ptsPerInvaderCol*colPerLevel
levelsToBeat = 3
# ptsPerLevel*levelsToBeat ~= 3000
reward_threshold = 2200
callback_on_best = StopTrainingOnRewardThreshold(reward_threshold=reward_threshold, verbose=1)
eval_callback = EvalCallback(vec_env, callback_on_new_best=callback_on_best, verbose=1)

# %%
model.learn(total_timesteps=30000000, callback=[checkpoint_callback], reset_num_timesteps=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    value_loss           | 0.131     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.05e+03   |
# |    ep_rew_mean          | 462        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1595       |
# |    time_elapsed         | 69877      |
# |    total_timesteps      | 26132480   |
# | train/                  |            |
# |    approx_kl            | 0.44387078 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.341     |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0387     |
# |    n_updates            | 15940      |
# |    policy_gradient_loss | -0.015     |
# |    value_loss           | 0.121      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3e+03     |
# |    ep_rew_mean          | 449       |
# | time/                   |           |
# |    fps                  | 373       |
# |    iterations           | 1596      |
# |    time_elapsed         | 69921     |
# |    total_timesteps      | 26148864  |
# | train/                  |           |
# |    approx_kl            | 0.4753169 |
# |    clip_fraction        | 0.239     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.355    |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0158   |
# |    n_updates            | 15950     |
# |    policy_gradient_loss | -0.0153   |
# |    value_loss           | 0.118     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.09e+03   |
# |    ep_rew_mean          | 468        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1597       |
# |    time_elapsed         | 69964      |
# |    total_timesteps      | 26165248   |
# | train/                  |            |
# |    approx_kl            | 0.40947467 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.338     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0527     |
# |    n_updates            | 15960      |
# |    policy_gradient_loss | -0.0139    |
# |    value_loss           | 0.139      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.14e+03   |
# |    ep_rew_mean          | 477        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1598       |
# |    time_elapsed         | 70008      |
# |    total_timesteps      | 26181632   |
# | train/                  |            |
# |    approx_kl            | 0.49795872 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.33      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00967    |
# |    n_updates            | 15970      |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 0.112      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.14e+03  |
# |    ep_rew_mean          | 475       |
# | time/                   |           |
# |    fps                  | 373       |
# |    iterations           | 1599      |
# |    time_elapsed         | 70051     |
# |    total_timesteps      | 26198016  |
# | train/                  |           |
# |    approx_kl            | 0.4338829 |
# |    clip_fraction        | 0.237     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.343    |
# |    explained_variance   | 0.958     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.013     |
# |    n_updates            | 15980     |
# |    policy_gradient_loss | -0.0167   |
# |    value_loss           | 0.112     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.15e+03   |
# |    ep_rew_mean          | 488        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1600       |
# |    time_elapsed         | 70094      |
# |    total_timesteps      | 26214400   |
# | train/                  |            |
# |    approx_kl            | 0.40995646 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.338     |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0143     |
# |    n_updates            | 15990      |
# |    policy_gradient_loss | -0.0168    |
# |    value_loss           | 0.1        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.18e+03   |
# |    ep_rew_mean          | 505        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1601       |
# |    time_elapsed         | 70137      |
# |    total_timesteps      | 26230784   |
# | train/                  |            |
# |    approx_kl            | 0.46869168 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.314     |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0369     |
# |    n_updates            | 16000      |
# |    policy_gradient_loss | -0.0144    |
# |    value_loss           | 0.113      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.08e+03   |
# |    ep_rew_mean          | 490        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1602       |
# |    time_elapsed         | 70181      |
# |    total_timesteps      | 26247168   |
# | train/                  |            |
# |    approx_kl            | 0.49932098 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.318     |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0657     |
# |    n_updates            | 16010      |
# |    policy_gradient_loss | -0.0155    |
# |    value_loss           | 0.109      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.04e+03   |
# |    ep_rew_mean          | 481        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1603       |
# |    time_elapsed         | 70224      |
# |    total_timesteps      | 26263552   |
# | train/                  |            |
# |    approx_kl            | 0.47156012 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.335     |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00575   |
# |    n_updates            | 16020      |
# |    policy_gradient_loss | -0.015     |
# |    value_loss           | 0.13       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.03e+03  |
# |    ep_rew_mean          | 475       |
# | time/                   |           |
# |    fps                  | 373       |
# |    iterations           | 1604      |
# |    time_elapsed         | 70268     |
# |    total_timesteps      | 26279936  |
# | train/                  |           |
# |    approx_kl            | 0.508175  |
# |    clip_fraction        | 0.261     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.353    |
# |    explained_variance   | 0.933     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0226    |
# |    n_updates            | 16030     |
# |    policy_gradient_loss | -3.69e-05 |
# |    value_loss           | 0.145     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.01e+03   |
# |    ep_rew_mean          | 473        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1605       |
# |    time_elapsed         | 70311      |
# |    total_timesteps      | 26296320   |
# | train/                  |            |
# |    approx_kl            | 0.49903396 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.325     |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0274    |
# |    n_updates            | 16040      |
# |    policy_gradient_loss | -0.014     |
# |    value_loss           | 0.119      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.02e+03   |
# |    ep_rew_mean          | 458        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 1606       |
# |    time_elapsed         | 70355      |
# |    total_timesteps      | 26312704   |
# | train/                  |            |
# |    approx_kl            | 0.48242196 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.339     |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0131     |
# |    n_updates            | 16050      |
# |    policy_gradient_loss | -0.0159    |
# |    value_loss           | 0.121      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.05e+03   |
# |    ep_rew_mean          | 454        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1607       |
# |    time_elapsed         | 70398      |
# |    total_timesteps      | 26329088   |
# | train/                  |            |
# |    approx_kl            | 0.44308203 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.34      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0182     |
# |    n_updates            | 16060      |
# |    policy_gradient_loss | -0.0173    |
# |    value_loss           | 0.123      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.13e+03   |
# |    ep_rew_mean          | 466        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1608       |
# |    time_elapsed         | 70441      |
# |    total_timesteps      | 26345472   |
# | train/                  |            |
# |    approx_kl            | 0.54118246 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.309     |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0159    |
# |    n_updates            | 16070      |
# |    policy_gradient_loss | -0.0148    |
# |    value_loss           | 0.118      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.09e+03   |
# |    ep_rew_mean          | 460        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1609       |
# |    time_elapsed         | 70484      |
# |    total_timesteps      | 26361856   |
# | train/                  |            |
# |    approx_kl            | 0.52251405 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.319     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0122    |
# |    n_updates            | 16080      |
# |    policy_gradient_loss | -0.0123    |
# |    value_loss           | 0.123      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.1e+03    |
# |    ep_rew_mean          | 468        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1610       |
# |    time_elapsed         | 70528      |
# |    total_timesteps      | 26378240   |
# | train/                  |            |
# |    approx_kl            | 0.45956016 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.319     |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.015      |
# |    n_updates            | 16090      |
# |    policy_gradient_loss | -0.0167    |
# |    value_loss           | 0.129      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.11e+03   |
# |    ep_rew_mean          | 478        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1611       |
# |    time_elapsed         | 70571      |
# |    total_timesteps      | 26394624   |
# | train/                  |            |
# |    approx_kl            | 0.45936915 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.31      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0138    |
# |    n_updates            | 16100      |
# |    policy_gradient_loss | -0.0162    |
# |    value_loss           | 0.117      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.13e+03   |
# |    ep_rew_mean          | 484        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1612       |
# |    time_elapsed         | 70614      |
# |    total_timesteps      | 26411008   |
# | train/                  |            |
# |    approx_kl            | 0.46518946 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.308     |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000325   |
# |    n_updates            | 16110      |
# |    policy_gradient_loss | -0.0158    |
# |    value_loss           | 0.137      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.12e+03   |
# |    ep_rew_mean          | 495        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1613       |
# |    time_elapsed         | 70658      |
# |    total_timesteps      | 26427392   |
# | train/                  |            |
# |    approx_kl            | 0.48289752 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.326     |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0107    |
# |    n_updates            | 16120      |
# |    policy_gradient_loss | -0.0149    |
# |    value_loss           | 0.114      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.07e+03  |
# |    ep_rew_mean          | 485       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1614      |
# |    time_elapsed         | 70701     |
# |    total_timesteps      | 26443776  |
# | train/                  |           |
# |    approx_kl            | 0.5086334 |
# |    clip_fraction        | 0.249     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.316    |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0276   |
# |    n_updates            | 16130     |
# |    policy_gradient_loss | -0.0164   |
# |    value_loss           | 0.11      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.05e+03  |
# |    ep_rew_mean          | 480       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1615      |
# |    time_elapsed         | 70745     |
# |    total_timesteps      | 26460160  |
# | train/                  |           |
# |    approx_kl            | 0.5265921 |
# |    clip_fraction        | 0.249     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.337    |
# |    explained_variance   | 0.958     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00679   |
# |    n_updates            | 16140     |
# |    policy_gradient_loss | -0.0152   |
# |    value_loss           | 0.113     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.05e+03   |
# |    ep_rew_mean          | 476        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1616       |
# |    time_elapsed         | 70788      |
# |    total_timesteps      | 26476544   |
# | train/                  |            |
# |    approx_kl            | 0.47595215 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.309     |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0122     |
# |    n_updates            | 16150      |
# |    policy_gradient_loss | -0.0151    |
# |    value_loss           | 0.116      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.06e+03  |
# |    ep_rew_mean          | 465       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1617      |
# |    time_elapsed         | 70831     |
# |    total_timesteps      | 26492928  |
# | train/                  |           |
# |    approx_kl            | 0.5773552 |
# |    clip_fraction        | 0.252     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.328    |
# |    explained_variance   | 0.953     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0151    |
# |    n_updates            | 16160     |
# |    policy_gradient_loss | -0.0148   |
# |    value_loss           | 0.122     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.03e+03   |
# |    ep_rew_mean          | 458        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1618       |
# |    time_elapsed         | 70874      |
# |    total_timesteps      | 26509312   |
# | train/                  |            |
# |    approx_kl            | 0.47442424 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.316     |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0125     |
# |    n_updates            | 16170      |
# |    policy_gradient_loss | -0.0159    |
# |    value_loss           | 0.116      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.12e+03   |
# |    ep_rew_mean          | 470        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1619       |
# |    time_elapsed         | 70917      |
# |    total_timesteps      | 26525696   |
# | train/                  |            |
# |    approx_kl            | 0.54034054 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.302     |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0182    |
# |    n_updates            | 16180      |
# |    policy_gradient_loss | -0.0135    |
# |    value_loss           | 0.131      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.14e+03  |
# |    ep_rew_mean          | 469       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1620      |
# |    time_elapsed         | 70961     |
# |    total_timesteps      | 26542080  |
# | train/                  |           |
# |    approx_kl            | 0.4974063 |
# |    clip_fraction        | 0.24      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.297    |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00288   |
# |    n_updates            | 16190     |
# |    policy_gradient_loss | -0.0122   |
# |    value_loss           | 0.143     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.16e+03   |
# |    ep_rew_mean          | 471        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1621       |
# |    time_elapsed         | 71004      |
# |    total_timesteps      | 26558464   |
# | train/                  |            |
# |    approx_kl            | 0.47916803 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.3       |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.013      |
# |    n_updates            | 16200      |
# |    policy_gradient_loss | -0.00712   |
# |    value_loss           | 0.132      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.17e+03   |
# |    ep_rew_mean          | 481        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1622       |
# |    time_elapsed         | 71047      |
# |    total_timesteps      | 26574848   |
# | train/                  |            |
# |    approx_kl            | 0.47195092 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.293     |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00216    |
# |    n_updates            | 16210      |
# |    policy_gradient_loss | -0.0147    |
# |    value_loss           | 0.111      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.16e+03   |
# |    ep_rew_mean          | 479        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1623       |
# |    time_elapsed         | 71091      |
# |    total_timesteps      | 26591232   |
# | train/                  |            |
# |    approx_kl            | 0.53886867 |
# |    clip_fraction        | 0.241      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.298     |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0259    |
# |    n_updates            | 16220      |
# |    policy_gradient_loss | -0.00948   |
# |    value_loss           | 0.12       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.22e+03   |
# |    ep_rew_mean          | 479        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1624       |
# |    time_elapsed         | 71134      |
# |    total_timesteps      | 26607616   |
# | train/                  |            |
# |    approx_kl            | 0.44608796 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.296     |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.011      |
# |    n_updates            | 16230      |
# |    policy_gradient_loss | -0.0171    |
# |    value_loss           | 0.14       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.23e+03   |
# |    ep_rew_mean          | 482        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1625       |
# |    time_elapsed         | 71177      |
# |    total_timesteps      | 26624000   |
# | train/                  |            |
# |    approx_kl            | 0.57435656 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.346     |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.049     |
# |    n_updates            | 16240      |
# |    policy_gradient_loss | -0.0142    |
# |    value_loss           | 0.123      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.18e+03   |
# |    ep_rew_mean          | 480        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1626       |
# |    time_elapsed         | 71221      |
# |    total_timesteps      | 26640384   |
# | train/                  |            |
# |    approx_kl            | 0.44537148 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.302     |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0289    |
# |    n_updates            | 16250      |
# |    policy_gradient_loss | -0.0123    |
# |    value_loss           | 0.12       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.14e+03   |
# |    ep_rew_mean          | 460        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1627       |
# |    time_elapsed         | 71264      |
# |    total_timesteps      | 26656768   |
# | train/                  |            |
# |    approx_kl            | 0.54555786 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.297     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00521   |
# |    n_updates            | 16260      |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 0.123      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.12e+03  |
# |    ep_rew_mean          | 450       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1628      |
# |    time_elapsed         | 71308     |
# |    total_timesteps      | 26673152  |
# | train/                  |           |
# |    approx_kl            | 0.5530812 |
# |    clip_fraction        | 0.256     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.337    |
# |    explained_variance   | 0.943     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00654   |
# |    n_updates            | 16270     |
# |    policy_gradient_loss | -0.0147   |
# |    value_loss           | 0.133     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.12e+03   |
# |    ep_rew_mean          | 452        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1629       |
# |    time_elapsed         | 71351      |
# |    total_timesteps      | 26689536   |
# | train/                  |            |
# |    approx_kl            | 0.48774636 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.322     |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000742   |
# |    n_updates            | 16280      |
# |    policy_gradient_loss | -0.0141    |
# |    value_loss           | 0.126      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.12e+03   |
# |    ep_rew_mean          | 443        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1630       |
# |    time_elapsed         | 71394      |
# |    total_timesteps      | 26705920   |
# | train/                  |            |
# |    approx_kl            | 0.61228913 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.314     |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0161     |
# |    n_updates            | 16290      |
# |    policy_gradient_loss | -0.0154    |
# |    value_loss           | 0.116      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.06e+03  |
# |    ep_rew_mean          | 440       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1631      |
# |    time_elapsed         | 71438     |
# |    total_timesteps      | 26722304  |
# | train/                  |           |
# |    approx_kl            | 0.5484329 |
# |    clip_fraction        | 0.258     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.304    |
# |    explained_variance   | 0.948     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00821   |
# |    n_updates            | 16300     |
# |    policy_gradient_loss | -0.0144   |
# |    value_loss           | 0.122     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.1e+03   |
# |    ep_rew_mean          | 464       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1632      |
# |    time_elapsed         | 71481     |
# |    total_timesteps      | 26738688  |
# | train/                  |           |
# |    approx_kl            | 0.4962849 |
# |    clip_fraction        | 0.246     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.307    |
# |    explained_variance   | 0.934     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0342   |
# |    n_updates            | 16310     |
# |    policy_gradient_loss | -0.0153   |
# |    value_loss           | 0.132     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.13e+03  |
# |    ep_rew_mean          | 468       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1633      |
# |    time_elapsed         | 71525     |
# |    total_timesteps      | 26755072  |
# | train/                  |           |
# |    approx_kl            | 0.5919091 |
# |    clip_fraction        | 0.246     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.312    |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.021     |
# |    n_updates            | 16320     |
# |    policy_gradient_loss | -0.0174   |
# |    value_loss           | 0.109     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.11e+03   |
# |    ep_rew_mean          | 476        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1634       |
# |    time_elapsed         | 71568      |
# |    total_timesteps      | 26771456   |
# | train/                  |            |
# |    approx_kl            | 0.48859942 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.29      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0164    |
# |    n_updates            | 16330      |
# |    policy_gradient_loss | -0.0163    |
# |    value_loss           | 0.115      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.03e+03   |
# |    ep_rew_mean          | 463        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1635       |
# |    time_elapsed         | 71611      |
# |    total_timesteps      | 26787840   |
# | train/                  |            |
# |    approx_kl            | 0.47680995 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.289     |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00546    |
# |    n_updates            | 16340      |
# |    policy_gradient_loss | -0.0161    |
# |    value_loss           | 0.0997     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.09e+03   |
# |    ep_rew_mean          | 476        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1636       |
# |    time_elapsed         | 71654      |
# |    total_timesteps      | 26804224   |
# | train/                  |            |
# |    approx_kl            | 0.58302057 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.307     |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00667    |
# |    n_updates            | 16350      |
# |    policy_gradient_loss | -0.0169    |
# |    value_loss           | 0.122      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.16e+03   |
# |    ep_rew_mean          | 492        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1637       |
# |    time_elapsed         | 71698      |
# |    total_timesteps      | 26820608   |
# | train/                  |            |
# |    approx_kl            | 0.59533036 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.277     |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00173   |
# |    n_updates            | 16360      |
# |    policy_gradient_loss | -0.0146    |
# |    value_loss           | 0.108      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.15e+03  |
# |    ep_rew_mean          | 491       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1638      |
# |    time_elapsed         | 71741     |
# |    total_timesteps      | 26836992  |
# | train/                  |           |
# |    approx_kl            | 0.5517653 |
# |    clip_fraction        | 0.255     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.282    |
# |    explained_variance   | 0.96      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0566    |
# |    n_updates            | 16370     |
# |    policy_gradient_loss | -0.0152   |
# |    value_loss           | 0.105     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.18e+03   |
# |    ep_rew_mean          | 485        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1639       |
# |    time_elapsed         | 71784      |
# |    total_timesteps      | 26853376   |
# | train/                  |            |
# |    approx_kl            | 0.65790844 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.259     |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0141    |
# |    n_updates            | 16380      |
# |    policy_gradient_loss | -0.0118    |
# |    value_loss           | 0.113      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.23e+03  |
# |    ep_rew_mean          | 499       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1640      |
# |    time_elapsed         | 71828     |
# |    total_timesteps      | 26869760  |
# | train/                  |           |
# |    approx_kl            | 0.6230022 |
# |    clip_fraction        | 0.237     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.246    |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0377    |
# |    n_updates            | 16390     |
# |    policy_gradient_loss | -0.0129   |
# |    value_loss           | 0.102     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.16e+03  |
# |    ep_rew_mean          | 487       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1641      |
# |    time_elapsed         | 71871     |
# |    total_timesteps      | 26886144  |
# | train/                  |           |
# |    approx_kl            | 0.5644162 |
# |    clip_fraction        | 0.231     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.255    |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00638   |
# |    n_updates            | 16400     |
# |    policy_gradient_loss | -0.0141   |
# |    value_loss           | 0.108     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.05e+03  |
# |    ep_rew_mean          | 481       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1642      |
# |    time_elapsed         | 71915     |
# |    total_timesteps      | 26902528  |
# | train/                  |           |
# |    approx_kl            | 0.5825826 |
# |    clip_fraction        | 0.228     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.254    |
# |    explained_variance   | 0.963     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0063   |
# |    n_updates            | 16410     |
# |    policy_gradient_loss | -0.0111   |
# |    value_loss           | 0.115     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.04e+03  |
# |    ep_rew_mean          | 483       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1643      |
# |    time_elapsed         | 71958     |
# |    total_timesteps      | 26918912  |
# | train/                  |           |
# |    approx_kl            | 0.5471839 |
# |    clip_fraction        | 0.23      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.251    |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00645   |
# |    n_updates            | 16420     |
# |    policy_gradient_loss | -0.0124   |
# |    value_loss           | 0.117     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.92e+03  |
# |    ep_rew_mean          | 469       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1644      |
# |    time_elapsed         | 72002     |
# |    total_timesteps      | 26935296  |
# | train/                  |           |
# |    approx_kl            | 0.5185882 |
# |    clip_fraction        | 0.239     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.256    |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0205    |
# |    n_updates            | 16430     |
# |    policy_gradient_loss | -0.0131   |
# |    value_loss           | 0.115     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.88e+03  |
# |    ep_rew_mean          | 456       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1645      |
# |    time_elapsed         | 72045     |
# |    total_timesteps      | 26951680  |
# | train/                  |           |
# |    approx_kl            | 0.5430156 |
# |    clip_fraction        | 0.23      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.263    |
# |    explained_variance   | 0.947     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00731   |
# |    n_updates            | 16440     |
# |    policy_gradient_loss | -0.0154   |
# |    value_loss           | 0.141     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.97e+03  |
# |    ep_rew_mean          | 468       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1646      |
# |    time_elapsed         | 72088     |
# |    total_timesteps      | 26968064  |
# | train/                  |           |
# |    approx_kl            | 0.5638099 |
# |    clip_fraction        | 0.232     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.244    |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.023     |
# |    n_updates            | 16450     |
# |    policy_gradient_loss | -0.00962  |
# |    value_loss           | 0.13      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.02e+03   |
# |    ep_rew_mean          | 469        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1647       |
# |    time_elapsed         | 72132      |
# |    total_timesteps      | 26984448   |
# | train/                  |            |
# |    approx_kl            | 0.46546152 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.26      |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00546   |
# |    n_updates            | 16460      |
# |    policy_gradient_loss | -0.0109    |
# |    value_loss           | 0.127      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 3.08e+03 |
# |    ep_rew_mean          | 468      |
# | time/                   |          |
# |    fps                  | 374      |
# |    iterations           | 1648     |
# |    time_elapsed         | 72175    |
# |    total_timesteps      | 27000832 |
# | train/                  |          |
# |    approx_kl            | 0.535951 |
# |    clip_fraction        | 0.247    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.263   |
# |    explained_variance   | 0.948    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0137   |
# |    n_updates            | 16470    |
# |    policy_gradient_loss | -0.0126  |
# |    value_loss           | 0.115    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 3.1e+03  |
# |    ep_rew_mean          | 469      |
# | time/                   |          |
# |    fps                  | 374      |
# |    iterations           | 1649     |
# |    time_elapsed         | 72218    |
# |    total_timesteps      | 27017216 |
# | train/                  |          |
# |    approx_kl            | 0.494035 |
# |    clip_fraction        | 0.245    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.277   |
# |    explained_variance   | 0.955    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.03     |
# |    n_updates            | 16480    |
# |    policy_gradient_loss | -0.012   |
# |    value_loss           | 0.108    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.24e+03   |
# |    ep_rew_mean          | 490        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1650       |
# |    time_elapsed         | 72262      |
# |    total_timesteps      | 27033600   |
# | train/                  |            |
# |    approx_kl            | 0.59292537 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.26      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00751    |
# |    n_updates            | 16490      |
# |    policy_gradient_loss | -0.0148    |
# |    value_loss           | 0.114      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.21e+03   |
# ...
# |    fps                  | 374        |
# |    iterations           | 1814       |
# |    time_elapsed         | 79386      |
# |    total_timesteps      | 29720576   |
# | train/                  |            |
# |    approx_kl            | 0.42043883 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.273     |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0102     |
# |    n_updates            | 18130      |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 0.118      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.2e+03    |
# |    ep_rew_mean          | 487        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1815       |
# |    time_elapsed         | 79429      |
# |    total_timesteps      | 29736960   |
# | train/                  |            |
# |    approx_kl            | 0.55353117 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.279     |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00847   |
# |    n_updates            | 18140      |
# |    policy_gradient_loss | -0.0167    |
# |    value_loss           | 0.122      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.2e+03    |
# |    ep_rew_mean          | 489        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1816       |
# |    time_elapsed         | 79473      |
# |    total_timesteps      | 29753344   |
# | train/                  |            |
# |    approx_kl            | 0.48461464 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.278     |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0061    |
# |    n_updates            | 18150      |
# |    policy_gradient_loss | -0.0141    |
# |    value_loss           | 0.116      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.18e+03   |
# |    ep_rew_mean          | 490        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1817       |
# |    time_elapsed         | 79516      |
# |    total_timesteps      | 29769728   |
# | train/                  |            |
# |    approx_kl            | 0.45351642 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.264     |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0154    |
# |    n_updates            | 18160      |
# |    policy_gradient_loss | -0.0157    |
# |    value_loss           | 0.118      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.22e+03   |
# |    ep_rew_mean          | 492        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1818       |
# |    time_elapsed         | 79559      |
# |    total_timesteps      | 29786112   |
# | train/                  |            |
# |    approx_kl            | 0.46121207 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.268     |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0138    |
# |    n_updates            | 18170      |
# |    policy_gradient_loss | -0.0141    |
# |    value_loss           | 0.109      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.15e+03  |
# |    ep_rew_mean          | 478       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1819      |
# |    time_elapsed         | 79603     |
# |    total_timesteps      | 29802496  |
# | train/                  |           |
# |    approx_kl            | 0.4729467 |
# |    clip_fraction        | 0.25      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.273    |
# |    explained_variance   | 0.963     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00631   |
# |    n_updates            | 18180     |
# |    policy_gradient_loss | -0.0126   |
# |    value_loss           | 0.109     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.15e+03   |
# |    ep_rew_mean          | 470        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1820       |
# |    time_elapsed         | 79646      |
# |    total_timesteps      | 29818880   |
# | train/                  |            |
# |    approx_kl            | 0.43283495 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.243     |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0118     |
# |    n_updates            | 18190      |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 0.11       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.19e+03  |
# |    ep_rew_mean          | 485       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1821      |
# |    time_elapsed         | 79689     |
# |    total_timesteps      | 29835264  |
# | train/                  |           |
# |    approx_kl            | 0.4472978 |
# |    clip_fraction        | 0.239     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.257    |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00925  |
# |    n_updates            | 18200     |
# |    policy_gradient_loss | -0.0146   |
# |    value_loss           | 0.117     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.15e+03   |
# |    ep_rew_mean          | 481        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1822       |
# |    time_elapsed         | 79733      |
# |    total_timesteps      | 29851648   |
# | train/                  |            |
# |    approx_kl            | 0.42310637 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.25      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000639   |
# |    n_updates            | 18210      |
# |    policy_gradient_loss | -0.0149    |
# |    value_loss           | 0.111      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.11e+03  |
# |    ep_rew_mean          | 483       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1823      |
# |    time_elapsed         | 79776     |
# |    total_timesteps      | 29868032  |
# | train/                  |           |
# |    approx_kl            | 0.4578244 |
# |    clip_fraction        | 0.244     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.264    |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00443  |
# |    n_updates            | 18220     |
# |    policy_gradient_loss | -0.011    |
# |    value_loss           | 0.126     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.11e+03   |
# |    ep_rew_mean          | 491        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1824       |
# |    time_elapsed         | 79821      |
# |    total_timesteps      | 29884416   |
# | train/                  |            |
# |    approx_kl            | 0.48832634 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.293     |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0134     |
# |    n_updates            | 18230      |
# |    policy_gradient_loss | -0.0137    |
# |    value_loss           | 0.116      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+03  |
# |    ep_rew_mean          | 489       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1825      |
# |    time_elapsed         | 79864     |
# |    total_timesteps      | 29900800  |
# | train/                  |           |
# |    approx_kl            | 0.5069928 |
# |    clip_fraction        | 0.241     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.272    |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0105    |
# |    n_updates            | 18240     |
# |    policy_gradient_loss | -0.0139   |
# |    value_loss           | 0.135     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.12e+03  |
# |    ep_rew_mean          | 491       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1826      |
# |    time_elapsed         | 79908     |
# |    total_timesteps      | 29917184  |
# | train/                  |           |
# |    approx_kl            | 0.4606591 |
# |    clip_fraction        | 0.255     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.286    |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0434   |
# |    n_updates            | 18250     |
# |    policy_gradient_loss | -0.0137   |
# |    value_loss           | 0.115     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 3.14e+03 |
# |    ep_rew_mean          | 496      |
# | time/                   |          |
# |    fps                  | 374      |
# |    iterations           | 1827     |
# |    time_elapsed         | 79952    |
# |    total_timesteps      | 29933568 |
# | train/                  |          |
# |    approx_kl            | 0.458713 |
# |    clip_fraction        | 0.235    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.251   |
# |    explained_variance   | 0.952    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0899   |
# |    n_updates            | 18260    |
# |    policy_gradient_loss | -0.0156  |
# |    value_loss           | 0.121    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.25e+03   |
# |    ep_rew_mean          | 509        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1828       |
# |    time_elapsed         | 79997      |
# |    total_timesteps      | 29949952   |
# | train/                  |            |
# |    approx_kl            | 0.43658876 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.257     |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0496     |
# |    n_updates            | 18270      |
# |    policy_gradient_loss | -0.0132    |
# |    value_loss           | 0.144      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.33e+03  |
# |    ep_rew_mean          | 516       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1829      |
# |    time_elapsed         | 80041     |
# |    total_timesteps      | 29966336  |
# | train/                  |           |
# |    approx_kl            | 0.4291445 |
# |    clip_fraction        | 0.247     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.264    |
# |    explained_variance   | 0.96      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00985  |
# |    n_updates            | 18280     |
# |    policy_gradient_loss | -0.0137   |
# |    value_loss           | 0.102     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.25e+03   |
# |    ep_rew_mean          | 497        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1830       |
# |    time_elapsed         | 80084      |
# |    total_timesteps      | 29982720   |
# | train/                  |            |
# |    approx_kl            | 0.47413546 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.27      |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0135    |
# |    n_updates            | 18290      |
# |    policy_gradient_loss | -0.0167    |
# |    value_loss           | 0.0893     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.25e+03   |
# |    ep_rew_mean          | 493        |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 1831       |
# |    time_elapsed         | 80128      |
# |    total_timesteps      | 29999104   |
# | train/                  |            |
# |    approx_kl            | 0.42943776 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.282     |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.019      |
# |    n_updates            | 18300      |
# |    policy_gradient_loss | -0.0158    |
# |    value_loss           | 0.126      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.21e+03  |
# |    ep_rew_mean          | 486       |
# | time/                   |           |
# |    fps                  | 374       |
# |    iterations           | 1832      |
# |    time_elapsed         | 80171     |
# |    total_timesteps      | 30015488  |
# | train/                  |           |
# |    approx_kl            | 0.4512757 |
# |    clip_fraction        | 0.253     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.284    |
# |    explained_variance   | 0.965     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0269   |
# |    n_updates            | 18310     |
# |    policy_gradient_loss | -0.0142   |
# |    value_loss           | 0.0991    |
# ---------------------------------------

# %% [markdown]
# ## Download / Upload Trained Agent and Continue Training

# %% [markdown]
# Save and download trained model

# %%
from google.colab import files

# %%
model.save("ppoDefault_spaceInvaders")
files.download("ppoDefault_spaceInvaders.zip")

# %%
import time
# sleep for 60 seconds to finish downloading
time.sleep(60)

# %%
drive.flush_and_unmount()

# %%
# terminate sessions
# free resources
from google.colab import runtime
runtime.unassign()

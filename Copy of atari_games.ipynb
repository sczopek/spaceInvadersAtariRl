# %% [markdown]
# # Stable Baselines3 - Train on Atari Games
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Collecting stable-baselines3>=2.0.0a4 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading stable_baselines3-2.4.0a7-py3-none-any.whl.metadata (5.1 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.4.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.7.1)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (9.4.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.32.3)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 22.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (6.4.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Downloading stable_baselines3-2.4.0a7-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.9/182.9 kB 10.3 MB/s eta 0:00:00
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 41.9 MB/s eta 0:00:00
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.2 MB/s eta 0:00:00
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446661 sha256=872b5f2a44cadb3f9351f8b84e04a9a0f73e384103b4b0eaa849c68a082ba5a1
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-1.3.0 stable-baselines3-2.4.0a7

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# %%
from google.colab import files
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Training on Atari
#
# We will use atari wrapper (it will downsample the image and convert it to gray scale).
#
# About Atari preprocessing: [Frame Skipping and Pre-Processing for Deep Q-Networks on Atari 2600 Games](https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/)
#
# ![Pong](https://cdn-images-1.medium.com/max/800/1*UHYJE7lF8IDZS_U5SsAFUQ.gif)

# %%
# There already exists an environment generator that will make and wrap atari environments correctly.
env = make_atari_env("SpaceInvadersNoFrameskip-v4", n_envs=8, seed=0)
# Stack 4 frames
vec_env = VecFrameStack(env, n_stack=4)

# %%
import os
models_dir = "models/PPO"
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from stable_baselines3.common.callbacks import CheckpointCallback
# Save a checkpoint every 2_000_000 steps
checkpoint_callback = CheckpointCallback(save_freq=250000, save_path="./gdrive/MyDrive/models/PPO",
                                         name_prefix="ppo_spaceInvadersLvl4Train")

# %% [markdown]
# from collections import OrderedDict \n
# hyperParamsDictForPpo = OrderedDict([('batch_size', 256), ('clip_range', 0.001), ('ent_coef', 0.01), ('env_wrapper', ['stable_baselines3.common.atari_wrappers.AtariWrapper']), ('frame_stack', 4), ('learning_rate', 0.0001), ('n_envs', 8), ('n_epochs', 4), ('n_steps', 128), ('n_timesteps', 100000), ('policy', 'CnnPolicy'), ('vf_coef', 0.5), ('normalize', False)])

# %%
# model = PPO("CnnPolicy", vec_env, verbose=1, tensorboard_log="./gdrive/MyDrive/models/ppo_spaceinvaders_tensorboard/",
#             batch_size=256,
#             clip_range=0.001,
#             ent_coef=0.01,
#             learning_rate=0.0001,
#             n_epochs=4,
#             n_steps=128,
#             vf_coef=0.5
#             )
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model = PPO.load("/content/gdrive/MyDrive/models/PPO/ppo_spaceInvadersLvl4Train_33955088_steps", verbose=1, tensorboard_log="./gdrive/MyDrive/models/ppo_spaceinvaders_tensorboard/",
                 force_reset=False)
model.set_env(vec_env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# Stop training when the model reaches the reward threshold
ptsPerInvaderCol = 60
colPerLevel = 12
ptsPerLevel = ptsPerInvaderCol*colPerLevel
levelsToBeat = 3
# ptsPerLevel*levelsToBeat ~= 3000
reward_threshold = 2200
callback_on_best = StopTrainingOnRewardThreshold(reward_threshold=reward_threshold, verbose=1)
eval_callback = EvalCallback(vec_env, callback_on_new_best=callback_on_best, verbose=1)

# %%
timestepsPerLvl = 2000
gamesToPlay = 1e6
ttlTimeSteps = int(levelsToBeat*timestepsPerLvl*gamesToPlay)
print("ttlTimeSteps: ", ttlTimeSteps)
# Out:
# ttlTimeSteps:  6000000000

# %%
#!rm ./models/PPO/ppo*

# %%
model.learn(total_timesteps=30000000, callback=[checkpoint_callback], reset_num_timesteps=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    value_loss           | 0.87         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.79e+03      |
# |    ep_rew_mean          | 2.39e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29060         |
# |    time_elapsed         | 53593         |
# |    total_timesteps      | 63712528      |
# | train/                  |               |
# |    approx_kl            | 0.00065765623 |
# |    clip_fraction        | 0.861         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 0.943         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0635        |
# |    n_updates            | 266444        |
# |    policy_gradient_loss | 0.0013        |
# |    value_loss           | 0.199         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.79e+03     |
# |    ep_rew_mean          | 2.39e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29061        |
# |    time_elapsed         | 53594        |
# |    total_timesteps      | 63713552     |
# | train/                  |              |
# |    approx_kl            | 0.0008480326 |
# |    clip_fraction        | 0.843        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0742       |
# |    n_updates            | 266448       |
# |    policy_gradient_loss | 0.00119      |
# |    value_loss           | 0.251        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.79e+03      |
# |    ep_rew_mean          | 2.39e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29062         |
# |    time_elapsed         | 53596         |
# |    total_timesteps      | 63714576      |
# | train/                  |               |
# |    approx_kl            | 0.00042877917 |
# |    clip_fraction        | 0.816         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0.94          |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0908        |
# |    n_updates            | 266452        |
# |    policy_gradient_loss | 0.000779      |
# |    value_loss           | 0.261         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.79e+03      |
# |    ep_rew_mean          | 2.39e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29063         |
# |    time_elapsed         | 53598         |
# |    total_timesteps      | 63715600      |
# | train/                  |               |
# |    approx_kl            | 0.00029928685 |
# |    clip_fraction        | 0.811         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.95          |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0608        |
# |    n_updates            | 266456        |
# |    policy_gradient_loss | 0.000704      |
# |    value_loss           | 0.182         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.79e+03      |
# |    ep_rew_mean          | 2.39e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29064         |
# |    time_elapsed         | 53600         |
# |    total_timesteps      | 63716624      |
# | train/                  |               |
# |    approx_kl            | 0.00064813875 |
# |    clip_fraction        | 0.816         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0.933         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.132         |
# |    n_updates            | 266460        |
# |    policy_gradient_loss | 0.000873      |
# |    value_loss           | 0.327         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.79e+03     |
# |    ep_rew_mean          | 2.39e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29065        |
# |    time_elapsed         | 53601        |
# |    total_timesteps      | 63717648     |
# | train/                  |              |
# |    approx_kl            | 0.0009823698 |
# |    clip_fraction        | 0.836        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.153        |
# |    n_updates            | 266464       |
# |    policy_gradient_loss | 0.00212      |
# |    value_loss           | 0.47         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.79e+03     |
# |    ep_rew_mean          | 2.39e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29066        |
# |    time_elapsed         | 53603        |
# |    total_timesteps      | 63718672     |
# | train/                  |              |
# |    approx_kl            | 0.0010444876 |
# |    clip_fraction        | 0.85         |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0813       |
# |    n_updates            | 266468       |
# |    policy_gradient_loss | 0.00145      |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.79e+03     |
# |    ep_rew_mean          | 2.39e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29067        |
# |    time_elapsed         | 53605        |
# |    total_timesteps      | 63719696     |
# | train/                  |              |
# |    approx_kl            | 0.0006666977 |
# |    clip_fraction        | 0.836        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0896       |
# |    n_updates            | 266472       |
# |    policy_gradient_loss | 0.00102      |
# |    value_loss           | 0.238        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.79e+03      |
# |    ep_rew_mean          | 2.39e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29068         |
# |    time_elapsed         | 53607         |
# |    total_timesteps      | 63720720      |
# | train/                  |               |
# |    approx_kl            | 0.00072623946 |
# |    clip_fraction        | 0.826         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | 0.928         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.193         |
# |    n_updates            | 266476        |
# |    policy_gradient_loss | 0.00155       |
# |    value_loss           | 0.375         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.79e+03     |
# |    ep_rew_mean          | 2.39e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29069        |
# |    time_elapsed         | 53608        |
# |    total_timesteps      | 63721744     |
# | train/                  |              |
# |    approx_kl            | 0.0006468588 |
# |    clip_fraction        | 0.824        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0865       |
# |    n_updates            | 266480       |
# |    policy_gradient_loss | 0.00137      |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.79e+03     |
# |    ep_rew_mean          | 2.39e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29070        |
# |    time_elapsed         | 53610        |
# |    total_timesteps      | 63722768     |
# | train/                  |              |
# |    approx_kl            | 0.0006547932 |
# |    clip_fraction        | 0.849        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.098        |
# |    n_updates            | 266484       |
# |    policy_gradient_loss | 0.00078      |
# |    value_loss           | 0.239        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.72e+03      |
# |    ep_rew_mean          | 2.38e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29071         |
# |    time_elapsed         | 53612         |
# |    total_timesteps      | 63723792      |
# | train/                  |               |
# |    approx_kl            | 0.00040003733 |
# |    clip_fraction        | 0.813         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0.916         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.117         |
# |    n_updates            | 266488        |
# |    policy_gradient_loss | 0.00147       |
# |    value_loss           | 0.382         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.72e+03     |
# |    ep_rew_mean          | 2.38e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29072        |
# |    time_elapsed         | 53614        |
# |    total_timesteps      | 63724816     |
# | train/                  |              |
# |    approx_kl            | 0.0012461552 |
# |    clip_fraction        | 0.813        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.111        |
# |    n_updates            | 266492       |
# |    policy_gradient_loss | 0.00229      |
# |    value_loss           | 0.557        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.72e+03     |
# |    ep_rew_mean          | 2.38e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29073        |
# |    time_elapsed         | 53615        |
# |    total_timesteps      | 63725840     |
# | train/                  |              |
# |    approx_kl            | 0.0010838897 |
# |    clip_fraction        | 0.864        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.13         |
# |    n_updates            | 266496       |
# |    policy_gradient_loss | 0.00161      |
# |    value_loss           | 0.326        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.79e+03      |
# |    ep_rew_mean          | 2.39e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29074         |
# |    time_elapsed         | 53617         |
# |    total_timesteps      | 63726864      |
# | train/                  |               |
# |    approx_kl            | 0.00062892685 |
# |    clip_fraction        | 0.843         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.827         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.105         |
# |    n_updates            | 266500        |
# |    policy_gradient_loss | 0.00154       |
# |    value_loss           | 0.363         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.82e+03     |
# |    ep_rew_mean          | 2.4e+03      |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29075        |
# |    time_elapsed         | 53619        |
# |    total_timesteps      | 63727888     |
# | train/                  |              |
# |    approx_kl            | 0.0010488533 |
# |    clip_fraction        | 0.823        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0802       |
# |    n_updates            | 266504       |
# |    policy_gradient_loss | 0.00234      |
# |    value_loss           | 0.263        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.88e+03     |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29076        |
# |    time_elapsed         | 53621        |
# |    total_timesteps      | 63728912     |
# | train/                  |              |
# |    approx_kl            | 0.0006338082 |
# |    clip_fraction        | 0.837        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.126        |
# |    n_updates            | 266508       |
# |    policy_gradient_loss | 0.00228      |
# |    value_loss           | 0.357        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.89e+03     |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29077        |
# |    time_elapsed         | 53623        |
# |    total_timesteps      | 63729936     |
# | train/                  |              |
# |    approx_kl            | 0.0017194855 |
# |    clip_fraction        | 0.863        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.144        |
# |    n_updates            | 266512       |
# |    policy_gradient_loss | 0.0027       |
# |    value_loss           | 0.375        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.9e+03      |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29078        |
# |    time_elapsed         | 53624        |
# |    total_timesteps      | 63730960     |
# | train/                  |              |
# |    approx_kl            | 0.0005096907 |
# |    clip_fraction        | 0.852        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0651       |
# |    n_updates            | 266516       |
# |    policy_gradient_loss | 0.00157      |
# |    value_loss           | 0.203        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.97e+03     |
# |    ep_rew_mean          | 2.44e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29079        |
# |    time_elapsed         | 53626        |
# |    total_timesteps      | 63731984     |
# | train/                  |              |
# |    approx_kl            | 0.0006746732 |
# |    clip_fraction        | 0.842        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0394       |
# |    n_updates            | 266520       |
# |    policy_gradient_loss | 0.000723     |
# |    value_loss           | 0.15         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.88e+03     |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29080        |
# |    time_elapsed         | 53628        |
# |    total_timesteps      | 63733008     |
# | train/                  |              |
# |    approx_kl            | 0.0007176262 |
# |    clip_fraction        | 0.853        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0548       |
# |    n_updates            | 266524       |
# |    policy_gradient_loss | 0.00137      |
# |    value_loss           | 0.141        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.88e+03     |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29081        |
# |    time_elapsed         | 53630        |
# |    total_timesteps      | 63734032     |
# | train/                  |              |
# |    approx_kl            | 0.0007397994 |
# |    clip_fraction        | 0.802        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.149        |
# |    n_updates            | 266528       |
# |    policy_gradient_loss | 0.000922     |
# |    value_loss           | 0.357        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.88e+03     |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29082        |
# |    time_elapsed         | 53632        |
# |    total_timesteps      | 63735056     |
# | train/                  |              |
# |    approx_kl            | 0.0005014717 |
# |    clip_fraction        | 0.815        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0523       |
# |    n_updates            | 266532       |
# |    policy_gradient_loss | 0.00102      |
# |    value_loss           | 0.132        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.88e+03     |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29083        |
# |    time_elapsed         | 53633        |
# |    total_timesteps      | 63736080     |
# | train/                  |              |
# |    approx_kl            | 0.0007214574 |
# |    clip_fraction        | 0.855        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0624       |
# |    n_updates            | 266536       |
# |    policy_gradient_loss | 0.00112      |
# |    value_loss           | 0.201        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.88e+03     |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29084        |
# |    time_elapsed         | 53635        |
# |    total_timesteps      | 63737104     |
# | train/                  |              |
# |    approx_kl            | 0.0003551063 |
# |    clip_fraction        | 0.823        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0635       |
# |    n_updates            | 266540       |
# |    policy_gradient_loss | 0.000862     |
# |    value_loss           | 0.168        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.88e+03      |
# |    ep_rew_mean          | 2.42e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29085         |
# |    time_elapsed         | 53637         |
# |    total_timesteps      | 63738128      |
# | train/                  |               |
# |    approx_kl            | 0.00066234777 |
# |    clip_fraction        | 0.827         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | 0.966         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0871        |
# |    n_updates            | 266544        |
# |    policy_gradient_loss | 0.0018        |
# |    value_loss           | 0.29          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.88e+03     |
# |    ep_rew_mean          | 2.42e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29086        |
# |    time_elapsed         | 53639        |
# |    total_timesteps      | 63739152     |
# | train/                  |              |
# |    approx_kl            | 0.0010052584 |
# |    clip_fraction        | 0.849        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.106        |
# |    n_updates            | 266548       |
# |    policy_gradient_loss | 0.00214      |
# |    value_loss           | 0.365        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.88e+03      |
# |    ep_rew_mean          | 2.42e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29087         |
# |    time_elapsed         | 53640         |
# |    total_timesteps      | 63740176      |
# | train/                  |               |
# |    approx_kl            | 0.00035358383 |
# |    clip_fraction        | 0.813         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | 0.917         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0722        |
# |    n_updates            | 266552        |
# |    policy_gradient_loss | 0.000886      |
# |    value_loss           | 0.182         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.94e+03     |
# |    ep_rew_mean          | 2.44e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29088        |
# |    time_elapsed         | 53642        |
# |    total_timesteps      | 63741200     |
# | train/                  |              |
# |    approx_kl            | 0.0014114217 |
# |    clip_fraction        | 0.811        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.156        |
# |    n_updates            | 266556       |
# |    policy_gradient_loss | 0.00189      |
# |    value_loss           | 0.528        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.94e+03     |
# |    ep_rew_mean          | 2.44e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29089        |
# |    time_elapsed         | 53644        |
# |    total_timesteps      | 63742224     |
# | train/                  |              |
# |    approx_kl            | 0.0009478515 |
# |    clip_fraction        | 0.846        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.101        |
# |    n_updates            | 266560       |
# |    policy_gradient_loss | 0.00301      |
# |    value_loss           | 0.307        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.94e+03     |
# |    ep_rew_mean          | 2.44e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29090        |
# |    time_elapsed         | 53646        |
# |    total_timesteps      | 63743248     |
# | train/                  |              |
# |    approx_kl            | 0.0008290519 |
# |    clip_fraction        | 0.82         |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0728       |
# |    n_updates            | 266564       |
# |    policy_gradient_loss | 0.00109      |
# |    value_loss           | 0.215        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.94e+03     |
# |    ep_rew_mean          | 2.44e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29091        |
# |    time_elapsed         | 53648        |
# |    total_timesteps      | 63744272     |
# | train/                  |              |
# |    approx_kl            | 0.0006952194 |
# |    clip_fraction        | 0.825        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.35         |
# |    n_updates            | 266568       |
# |    policy_gradient_loss | 0.00257      |
# |    value_loss           | 0.843        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.94e+03     |
# |    ep_rew_mean          | 2.44e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29092        |
# |    time_elapsed         | 53649        |
# |    total_timesteps      | 63745296     |
# | train/                  |              |
# |    approx_kl            | 0.0007372038 |
# |    clip_fraction        | 0.823        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0791       |
# |    n_updates            | 266572       |
# |    policy_gradient_loss | 0.0012       |
# |    value_loss           | 0.225        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 2.48e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29093         |
# |    time_elapsed         | 53651         |
# |    total_timesteps      | 63746320      |
# | train/                  |               |
# |    approx_kl            | 0.00080832804 |
# |    clip_fraction        | 0.843         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0.921         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.12          |
# |    n_updates            | 266576        |
# |    policy_gradient_loss | 0.00157       |
# |    value_loss           | 0.355         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 2.5e+03      |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29094        |
# |    time_elapsed         | 53653        |
# |    total_timesteps      | 63747344     |
# | train/                  |              |
# |    approx_kl            | 0.0007085785 |
# |    clip_fraction        | 0.844        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0889       |
# |    n_updates            | 266580       |
# |    policy_gradient_loss | 0.00133      |
# |    value_loss           | 0.295        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 2.5e+03      |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29095        |
# |    time_elapsed         | 53655        |
# |    total_timesteps      | 63748368     |
# | train/                  |              |
# |    approx_kl            | 0.0010253965 |
# |    clip_fraction        | 0.835        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.827        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.201        |
# |    n_updates            | 266584       |
# |    policy_gradient_loss | 0.00104      |
# |    value_loss           | 0.57         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+04    |
# |    ep_rew_mean          | 2.5e+03     |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 29096       |
# |    time_elapsed         | 53656       |
# |    total_timesteps      | 63749392    |
# | train/                  |             |
# |    approx_kl            | 0.000624991 |
# |    clip_fraction        | 0.844       |
# |    clip_range           | 0.001       |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0773      |
# |    n_updates            | 266588      |
# |    policy_gradient_loss | 0.0011      |
# |    value_loss           | 0.274       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 2.5e+03       |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29097         |
# |    time_elapsed         | 53658         |
# |    total_timesteps      | 63750416      |
# | train/                  |               |
# |    approx_kl            | 0.00048411574 |
# |    clip_fraction        | 0.844         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 0.844         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0745        |
# |    n_updates            | 266592        |
# |    policy_gradient_loss | 0.00065       |
# |    value_loss           | 0.215         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 2.49e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29098        |
# |    time_elapsed         | 53660        |
# |    total_timesteps      | 63751440     |
# | train/                  |              |
# |    approx_kl            | 0.0007427092 |
# |    clip_fraction        | 0.858        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0795       |
# |    n_updates            | 266596       |
# |    policy_gradient_loss | 0.0038       |
# |    value_loss           | 0.27         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+04    |
# |    ep_rew_mean          | 2.49e+03    |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 29099       |
# |    time_elapsed         | 53662       |
# |    total_timesteps      | 63752464    |
# | train/                  |             |
# |    approx_kl            | 0.009729409 |
# |    clip_fraction        | 0.794       |
# |    clip_range           | 0.001       |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.164       |
# |    n_updates            | 266600      |
# |    policy_gradient_loss | 0.0088      |
# |    value_loss           | 0.541       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+04     |
# |    ep_rew_mean          | 2.51e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29100        |
# |    time_elapsed         | 53663        |
# |    total_timesteps      | 63753488     |
# | train/                  |              |
# |    approx_kl            | 0.0011286393 |
# |    clip_fraction        | 0.846        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0713       |
# |    n_updates            | 266604       |
# |    policy_gradient_loss | 0.00231      |
# |    value_loss           | 0.199        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+04     |
# |    ep_rew_mean          | 2.51e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29101        |
# |    time_elapsed         | 53665        |
# |    total_timesteps      | 63754512     |
# | train/                  |              |
# |    approx_kl            | 0.0029301285 |
# |    clip_fraction        | 0.874        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.167        |
# |    n_updates            | 266608       |
# |    policy_gradient_loss | 0.00548      |
# |    value_loss           | 0.491        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.02e+04      |
# |    ep_rew_mean          | 2.51e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29102         |
# |    time_elapsed         | 53667         |
# |    total_timesteps      | 63755536      |
# | train/                  |               |
# |    approx_kl            | 0.00095611234 |
# |    clip_fraction        | 0.884         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.885         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.141         |
# |    n_updates            | 266612        |
# |    policy_gradient_loss | 0.00333       |
# |    value_loss           | 0.349         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+04     |
# |    ep_rew_mean          | 2.52e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29103        |
# |    time_elapsed         | 53669        |
# |    total_timesteps      | 63756560     |
# | train/                  |              |
# |    approx_kl            | 0.0010565545 |
# |    clip_fraction        | 0.852        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0533       |
# |    n_updates            | 266616       |
# |    policy_gradient_loss | 0.00112      |
# |    value_loss           | 0.217        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+04     |
# |    ep_rew_mean          | 2.52e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29104        |
# |    time_elapsed         | 53671        |
# |    total_timesteps      | 63757584     |
# | train/                  |              |
# |    approx_kl            | 0.0015561937 |
# |    clip_fraction        | 0.854        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.1          |
# |    n_updates            | 266620       |
# |    policy_gradient_loss | 0.00336      |
# |    value_loss           | 0.289        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.02e+04      |
# |    ep_rew_mean          | 2.52e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29105         |
# |    time_elapsed         | 53672         |
# |    total_timesteps      | 63758608      |
# | train/                  |               |
# |    approx_kl            | 0.00090099673 |
# |    clip_fraction        | 0.808         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | 0.949         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0596        |
# |    n_updates            | 266624        |
# |    policy_gradient_loss | 0.00126       |
# |    value_loss           | 0.21          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+04     |
# |    ep_rew_mean          | 2.52e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29106        |
# |    time_elapsed         | 53674        |
# |    total_timesteps      | 63759632     |
# | train/                  |              |
# |    approx_kl            | 0.0007324318 |
# |    clip_fraction        | 0.838        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.146        |
# |    n_updates            | 266628       |
# |    policy_gradient_loss | 0.00215      |
# |    value_loss           | 0.321        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.02e+04      |
# |    ep_rew_mean          | 2.52e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29107         |
# |    time_elapsed         | 53676         |
# |    total_timesteps      | 63760656      |
# | train/                  |               |
# |    approx_kl            | 0.00094444933 |
# |    clip_fraction        | 0.827         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | 0.969         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0405        |
# |    n_updates            | 266632        |
# |    policy_gradient_loss | 0.00098       |
# |    value_loss           | 0.132         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.02e+04      |
# |    ep_rew_mean          | 2.52e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29108         |
# |    time_elapsed         | 53678         |
# |    total_timesteps      | 63761680      |
# | train/                  |               |
# |    approx_kl            | 0.00064440735 |
# |    clip_fraction        | 0.851         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | 0.818         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0753        |
# |    n_updates            | 266636        |
# |    policy_gradient_loss | 0.00111       |
# |    value_loss           | 0.259         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.02e+04      |
# |    ep_rew_mean          | 2.52e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29109         |
# |    time_elapsed         | 53680         |
# |    total_timesteps      | 63762704      |
# | train/                  |               |
# |    approx_kl            | 0.00039047957 |
# |    clip_fraction        | 0.794         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | 0.938         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0676        |
# |    n_updates            | 266640        |
# |    policy_gradient_loss | 0.000811      |
# |    value_loss           | 0.194         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+04     |
# |    ep_rew_mean          | 2.54e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29110        |
# |    time_elapsed         | 53681        |
# |    total_timesteps      | 63763728     |
# | train/                  |              |
# |    approx_kl            | 0.0006751249 |
# |    clip_fraction        | 0.803        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0639       |
# |    n_updates            | 266644       |
# |    policy_gradient_loss | 0.00103      |
# |    value_loss           | 0.218        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+04     |
# |    ep_rew_mean          | 2.54e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29111        |
# |    time_elapsed         | 53683        |
# |    total_timesteps      | 63764752     |
# | train/                  |              |
# |    approx_kl            | 0.0012699824 |
# |    clip_fraction        | 0.793        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.382        |
# |    n_updates            | 266648       |
# |    policy_gradient_loss | 0.00263      |
# |    value_loss           | 0.763        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.03e+04      |
# |    ep_rew_mean          | 2.54e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29112         |
# |    time_elapsed         | 53685         |
# |    total_timesteps      | 63765776      |
# | train/                  |               |
# |    approx_kl            | 0.00058791856 |
# |    clip_fraction        | 0.792         |
# |    clip_range           | 0.001         |
# ...
# |    total_timesteps      | 63937808     |
# | train/                  |              |
# |    approx_kl            | 0.0008678509 |
# |    clip_fraction        | 0.828        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.12         |
# |    n_updates            | 267324       |
# |    policy_gradient_loss | 0.00115      |
# |    value_loss           | 0.284        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.05e+04      |
# |    ep_rew_mean          | 2.61e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29281         |
# |    time_elapsed         | 53986         |
# |    total_timesteps      | 63938832      |
# | train/                  |               |
# |    approx_kl            | 0.00057571306 |
# |    clip_fraction        | 0.833         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.25         |
# |    explained_variance   | 0.958         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.052         |
# |    n_updates            | 267328        |
# |    policy_gradient_loss | 0.000845      |
# |    value_loss           | 0.174         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.05e+04      |
# |    ep_rew_mean          | 2.61e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29282         |
# |    time_elapsed         | 53988         |
# |    total_timesteps      | 63939856      |
# | train/                  |               |
# |    approx_kl            | 0.00077494746 |
# |    clip_fraction        | 0.765         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.11         |
# |    explained_variance   | 0.938         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.179         |
# |    n_updates            | 267332        |
# |    policy_gradient_loss | 0.00142       |
# |    value_loss           | 0.347         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | 2.61e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29283        |
# |    time_elapsed         | 53990        |
# |    total_timesteps      | 63940880     |
# | train/                  |              |
# |    approx_kl            | 0.0013209138 |
# |    clip_fraction        | 0.838        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.175        |
# |    n_updates            | 267336       |
# |    policy_gradient_loss | 0.00195      |
# |    value_loss           | 0.563        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | 2.61e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29284        |
# |    time_elapsed         | 53992        |
# |    total_timesteps      | 63941904     |
# | train/                  |              |
# |    approx_kl            | 0.0007474884 |
# |    clip_fraction        | 0.852        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0523       |
# |    n_updates            | 267340       |
# |    policy_gradient_loss | 0.000879     |
# |    value_loss           | 0.163        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.05e+04      |
# |    ep_rew_mean          | 2.61e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29285         |
# |    time_elapsed         | 53994         |
# |    total_timesteps      | 63942928      |
# | train/                  |               |
# |    approx_kl            | 0.00050530495 |
# |    clip_fraction        | 0.837         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | 0.945         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0697        |
# |    n_updates            | 267344        |
# |    policy_gradient_loss | 0.00124       |
# |    value_loss           | 0.23          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | 2.61e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29286        |
# |    time_elapsed         | 53995        |
# |    total_timesteps      | 63943952     |
# | train/                  |              |
# |    approx_kl            | 0.0009987524 |
# |    clip_fraction        | 0.813        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0717       |
# |    n_updates            | 267348       |
# |    policy_gradient_loss | 0.00177      |
# |    value_loss           | 0.269        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | 2.6e+03      |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29287        |
# |    time_elapsed         | 53997        |
# |    total_timesteps      | 63944976     |
# | train/                  |              |
# |    approx_kl            | 0.0006339309 |
# |    clip_fraction        | 0.817        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0942       |
# |    n_updates            | 267352       |
# |    policy_gradient_loss | 0.000968     |
# |    value_loss           | 0.281        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.04e+04     |
# |    ep_rew_mean          | 2.58e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29288        |
# |    time_elapsed         | 53999        |
# |    total_timesteps      | 63946000     |
# | train/                  |              |
# |    approx_kl            | 0.0018723771 |
# |    clip_fraction        | 0.773        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.561        |
# |    n_updates            | 267356       |
# |    policy_gradient_loss | 0.00412      |
# |    value_loss           | 0.994        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+04    |
# |    ep_rew_mean          | 2.6e+03     |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 29289       |
# |    time_elapsed         | 54001       |
# |    total_timesteps      | 63947024    |
# | train/                  |             |
# |    approx_kl            | 0.001827382 |
# |    clip_fraction        | 0.828       |
# |    clip_range           | 0.001       |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.294       |
# |    n_updates            | 267360      |
# |    policy_gradient_loss | 0.00341     |
# |    value_loss           | 0.552       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | 2.6e+03      |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29290        |
# |    time_elapsed         | 54002        |
# |    total_timesteps      | 63948048     |
# | train/                  |              |
# |    approx_kl            | 0.0016000051 |
# |    clip_fraction        | 0.874        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0467       |
# |    n_updates            | 267364       |
# |    policy_gradient_loss | 0.00213      |
# |    value_loss           | 0.161        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.03e+04      |
# |    ep_rew_mean          | 2.55e+03      |
# | time/                   |               |
# |    fps                  | 555           |
# |    iterations           | 29291         |
# |    time_elapsed         | 54004         |
# |    total_timesteps      | 63949072      |
# | train/                  |               |
# |    approx_kl            | 0.00061860593 |
# |    clip_fraction        | 0.855         |
# |    clip_range           | 0.001         |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.898         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0926        |
# |    n_updates            | 267368        |
# |    policy_gradient_loss | 0.00132       |
# |    value_loss           | 0.232         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+04     |
# |    ep_rew_mean          | 2.55e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29292        |
# |    time_elapsed         | 54006        |
# |    total_timesteps      | 63950096     |
# | train/                  |              |
# |    approx_kl            | 0.0021869373 |
# |    clip_fraction        | 0.789        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.155        |
# |    n_updates            | 267372       |
# |    policy_gradient_loss | 0.00287      |
# |    value_loss           | 0.49         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+04     |
# |    ep_rew_mean          | 2.55e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29293        |
# |    time_elapsed         | 54008        |
# |    total_timesteps      | 63951120     |
# | train/                  |              |
# |    approx_kl            | 0.0019210489 |
# |    clip_fraction        | 0.864        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.124        |
# |    n_updates            | 267376       |
# |    policy_gradient_loss | 0.00318      |
# |    value_loss           | 0.373        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+04     |
# |    ep_rew_mean          | 2.55e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29294        |
# |    time_elapsed         | 54010        |
# |    total_timesteps      | 63952144     |
# | train/                  |              |
# |    approx_kl            | 0.0010176499 |
# |    clip_fraction        | 0.85         |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0717       |
# |    n_updates            | 267380       |
# |    policy_gradient_loss | 0.00138      |
# |    value_loss           | 0.193        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+04     |
# |    ep_rew_mean          | 2.55e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29295        |
# |    time_elapsed         | 54011        |
# |    total_timesteps      | 63953168     |
# | train/                  |              |
# |    approx_kl            | 0.0016345109 |
# |    clip_fraction        | 0.857        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.118        |
# |    n_updates            | 267384       |
# |    policy_gradient_loss | 0.00309      |
# |    value_loss           | 0.305        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.04e+04     |
# |    ep_rew_mean          | 2.6e+03      |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29296        |
# |    time_elapsed         | 54013        |
# |    total_timesteps      | 63954192     |
# | train/                  |              |
# |    approx_kl            | 0.0011560594 |
# |    clip_fraction        | 0.855        |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0748       |
# |    n_updates            | 267388       |
# |    policy_gradient_loss | 0.00304      |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+04     |
# |    ep_rew_mean          | 2.57e+03     |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 29297        |
# |    time_elapsed         | 54015        |
# |    total_timesteps      | 63955216     |
# | train/                  |              |
# |    approx_kl            | 0.0007828662 |
# |    clip_fraction        | 0.82         |
# |    clip_range           | 0.001        |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.244        |
# |    n_updates            | 267392       |
# |    policy_gradient_loss | 0.0029       |
# |    value_loss           | 0.636        |
# ------------------------------------------

# %% [markdown]
# ## Download / Upload Trained Agent and Continue Training

# %% [markdown]
# Save and download trained model

# %%
from google.colab import files

# %%
model.save("ppo_spaceInvadersLvl4Train")
files.download("ppo_spaceInvadersLvl4Train.zip")

# %%
import time
# sleep for 60 seconds to finish downloading
time.sleep(60)

# %%
drive.flush_and_unmount()

# %%
# terminate sessions
# free resources
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# Upload train agent from your local machine

# %%
files.upload()

# %%
# !du -h ppo*

# %% [markdown]
# Load the agent, and then you can continue training

# %%
trained_model = PPO.load("ppo_spaceInvaders", verbose=1)
env = make_atari_env('SpaceInvadersNoFrameskip-v4', n_envs=4, seed=0)
env = VecFrameStack(env, n_stack=4)
trained_model.set_env(env)

# %%
trained_model.learn(int(0.5e6))

# %%
trained_model.save("ppo_spaceInvaders_2")
files.download("ppo_spaceInvaders_2.zip")

# %%
# !pip install renderlab

# %%
import gymnasium as gym
import renderlab as rl
from stable_baselines3.common.atari_wrappers import WarpFrame
import numpy as np

env = gym.make("SpaceInvadersNoFrameskip-v4", render_mode = "rgb_array")
env = rl.RenderFrame(env, "./output")

resizeFrame = WarpFrame(env, width=84, height=84)

observation, info = env.reset()

reward_list = []

while True:
  # rescale and duplicate obs so it work for vectorized model,
  # that expects 4 greyscale images
  obsForAgent = resizeFrame.observation(observation)
  obsForAgent = obsForAgent.squeeze()
  obsForAgent = np.repeat(obsForAgent[np.newaxis, :, :], 4, axis=0)
  action = model.predict(obsForAgent)
  observation, reward, terminated, truncated, info = env.step(action[0])

  reward_list.append(reward)

  #if terminated or truncated:
  if terminated:
    break

env.play()

# %%
tot_reward = 0
for rew in reward_list:
  tot_reward += rew

print("Total reward: ", tot_reward)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# There already exists an environment generator that will make and wrap atari environments correctly.
env = make_atari_env("SpaceInvadersNoFrameskip-v4", n_envs=8, seed=0)
# Stack 4 frames
vec_env = VecFrameStack(env, n_stack=4)


model = PPO.load("/content/gdrive/MyDrive/models/PPO/ppo_spaceInvadersLvl4Train_63955088_steps",
                 verbose=1,
                 force_reset=False)

# %%
observation = vec_env.reset()
model.set_env(vec_env)

reward_list = []
img_list = []
render_list = []
terminated_list = []
info_list = []
stepCounter = 0

while stepCounter<1000:
  action = model.predict(observation)
  observation, reward, terminated, info = vec_env.step(action[0])

  reward_list.append(reward)

  render_list.append(vec_env(render()))
  img_list.append(vec_env.get_images())
  terminated_list.append(terminated)
  info_list.append(info)

  stepCounter += 1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Wrapping the env in a VecTransposeImage.
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(

# %%
print(type(img_list[0]))
print(type(img_list[0][0]))
print(img_list[0][0].shape)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# (210, 160, 3)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
envIdx = 0
epLen = 0
numTrues = 0
for term in terminated_list:
  epLen += 1
  if term[envIdx]:
    numTrues += 1
    print(epLen)
    epLen = 0

print(numTrues)
print(len(terminated_list) - numTrues)
# Out:
# 728
# 1934
# 285
# 157
# 3906
# 508
# 598
# 846
# 8
# 9992
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
info = info_list[5]
type(info)
len(info)
info
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [{'lives': 3,
#   'episode_frame_number': 54,
#   'frame_number': 54,
#   'TimeLimit.truncated': False},
#  {'lives': 3,
#   'episode_frame_number': 37,
#   'frame_number': 37,
#   'TimeLimit.truncated': False},
#  {'lives': 3,
#   'episode_frame_number': 51,
#   'frame_number': 51,
#   'TimeLimit.truncated': False},
#  {'lives': 3,
#   'episode_frame_number': 57,
#   'frame_number': 57,
#   'TimeLimit.truncated': False},
#  {'lives': 3,
#   'episode_frame_number': 33,
#   'frame_number': 33,
#   'TimeLimit.truncated': False},
#  {'lives': 3,
#   'episode_frame_number': 61,
#   'frame_number': 61,
#   'TimeLimit.truncated': False},
#  {'lives': 3,
#   'episode_frame_number': 53,
#   'frame_number': 53,
#   'TimeLimit.truncated': False},
#  {'lives': 3,
#   'episode_frame_number': 46,
#   'frame_number': 46,
#   'TimeLimit.truncated': False}]

# %%
siEnv = make_atari_env("SpaceInvadersNoFrameskip-v4", n_envs=8, seed=0)
dir(siEnv)
siEnv.metadata
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'render_modes': ['human', 'rgb_array'],
#  'obs_types': {'grayscale', 'ram', 'rgb'}}

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# write whole video
# all games
import numpy as np
import cv2
from cv2 import cvtColor

envIdx = 1
size = 210, 160
fps = 61 # 32
out = cv2.VideoWriter('output61.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (size[1], size[0]), 1)
for idx in range( len(img_list) ):
    data = img_list[idx][envIdx]
    # out.write(data)
    out.write(cv2.cvtColor(data, cv2.COLOR_RGB2BGR))
out.release()

# %%
#########################################
# write each game in env0 to a separate file

import numpy as np
import cv2

size = 210, 160
fps = 32
envIdx = 1
mp4Suffix = '.mp4'
filePrefix = 'spaceInvadersPpoAgent35MframesGame'
game = 1
gameScore = 0
'''
for termIdx in range( len(img_list) ):
    gameScore += reward_list[termIdx][envIdx]
    if terminated_list[termIdx][envIdx]:
      break
vidFileName = filePrefix + str(game) + 'Score' + str(gameScore) + mp4Suffix
'''
vidFileName = filePrefix + str(game) + mp4Suffix
out = cv2.VideoWriter(vidFileName, cv2.VideoWriter_fourcc(*'mp4v'), fps, (size[1], size[0]), 1)
for idx in range( len(img_list) ):
    data = img_list[idx][envIdx]
    gameScore += reward_list[idx]
    # out.write(data)
    out.write(cv2.cvtColor(data, cv2.COLOR_RGB2BGR))
    if terminated_list[idx][envIdx]:
      out.release()
      game += 1
      gameScore = 0
      '''
      for termIdx in range(1, len(img_list) ):
        forwardIdx = idx + termIdx
        if forwardIdx>=len(img_list):
          break
        gameScore += reward_list[forwardIdx][envIdx]
        if terminated_list[forwardIdx][envIdx]:
          break
      # vidFileName = filePrefix + str(game) + 'Score' + str(gameScore) + mp4Suffix
      '''
      vidFileName = filePrefix + str(game) + mp4Suffix
      out = cv2.VideoWriter(vidFileName, cv2.VideoWriter_fourcc(*'mp4v'), fps, (size[1], size[0]), 1)


out.release()

# %%
# !rm /content/spaceInvadersPpoAgent35MframesGame*

# %%
size = 720*16//9, 720
duration = 2
fps = 25
out = cv2.VideoWriter('output.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (size[1], size[0]), False)
for _ in range(fps * duration):
    data = np.random.randint(0, 256, size, dtype='uint8')
    out.write(data)
out.release()

# %%
# !pip moviepy
# Out:
# ERROR: unknown command "moviepy"

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips



vidPrefix = "/content/spaceInvadersPpoAgent35MframesGame"
vidPrefix = "/content/"+filePrefix

clip_1 = VideoFileClip(vidPrefix + "7.mp4")
clip_2 = VideoFileClip(vidPrefix + "8.mp4")
clip_3 = VideoFileClip(vidPrefix + "9.mp4")
final_clip = concatenate_videoclips([clip_3,clip_1,clip_2])
# final_clip = concatenate_videoclips([clip_2, clip_1])
final_clip.write_videofile("game3.mp4")
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Moviepy - Building video game3.mp4.
# Moviepy - Writing video game3.mp4
# t:  63%|██████▎   | 1957/3084 [00:00<00:00, 2381.56it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/spaceInvadersPpoAgent35MframesGame9.mp4, 100800 bytes wanted but 0 bytes read,at frame 1989/1990, at time 62.16/62.16 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready game3.mp4

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# There already exists an environment generator that will make and wrap atari environments correctly.
env = make_atari_env("SpaceInvadersNoFrameskip-v4", n_envs=8, seed=0)
# Stack 4 frames
vec_env = VecFrameStack(env, n_stack=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
object_methods = [method_name for method_name in dir(vec_env)
                  if callable(getattr(vec_env, method_name))]

# %%
object_methods
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_get_indices',
#  '_get_target_envs',
#  '_obs_from_buf',
#  '_reset_options',
#  '_reset_seeds',
#  '_save_obs',
#  'close',
#  'env_is_wrapped',
#  'env_method',
#  'get_attr',
#  'get_images',
#  'getattr_depth_check',
#  'render',
#  'reset',
#  'seed',
#  'set_attr',
#  'set_options',
#  'step',
#  'step_async',
#  'step_wait']

# %%
object_methods = [method_name for method_name in dir(env)
                  if callable(getattr(env, method_name))]
object_methods
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_get_indices',
#  '_get_target_envs',
#  '_obs_from_buf',
#  '_reset_options',
#  '_reset_seeds',
#  '_save_obs',
#  'close',
#  'env_is_wrapped',
#  'env_method',
#  'get_attr',
#  'get_images',
#  'getattr_depth_check',
#  'render',
#  'reset',
#  'seed',
#  'set_attr',
#  'set_options',
#  'step',
#  'step_async',
#  'step_wait']

# %%
env.get_attr('score')
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.score to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.score` for environment variables or `env.get_wrapper_attr('score')` that will search the reminding wrappers.
#   logger.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c18af0b77dbd> in <cell line: 1>()
# ----> 1 env.get_attr('score')
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in get_attr(self, attr_name, indices)
#     116         """Return attribute from vectorized environment (see base class)."""
#     117         target_envs = self._get_target_envs(indices)
# --> 118         return [getattr(env_i, attr_name) for env_i in target_envs]
#     119
#     120     def set_attr(self, attr_name: str, value: Any, indices: VecEnvIndices = None) -> None:
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in <listcomp>(.0)
#     116         """Return attribute from vectorized environment (see base class)."""
#     117         target_envs = self._get_target_envs(indices)
# --> 118         return [getattr(env_i, attr_name) for env_i in target_envs]
#     119
#     120     def set_attr(self, attr_name: str, value: Any, indices: VecEnvIndices = None) -> None:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in __getattr__(self, name)
#     313             f"to get this variable you can do `env.unwrapped.{name}` for environment variables or `env.get_wrapper_attr('{name}')` that will search the reminding wrappers."
#     314         )
# --> 315         return getattr(self.env, name)
#     316
#     317     def get_wrapper_attr(self, name: str) -> Any:
#
# AttributeError: 'AtariEnv' object has no attribute 'score'

# %%
# possible fix for the color issue
video.write(cv2.cvtColor(data, cv2.COLOR_RGB2BGR))

# %% [markdown]
# OrderedDict([('batch_size', 256),
#              ('clip_range', 0.001),
#              ('ent_coef', 0.01),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('frame_stack', 4),
#              ('learning_rate', 0.0001),
#              ('n_envs', 8),
#              ('n_epochs', 4),
#              ('n_steps', 128),
#              ('n_timesteps', 100000),
#              ('policy', 'CnnPolicy'),
#              ('vf_coef', 0.5),
#              ('normalize', False)])
